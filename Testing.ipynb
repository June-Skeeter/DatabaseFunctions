# %% [markdown]
# # Reading & Writing to the Database

# %%
import DatabaseFunctions
import numpy as np
import importlib
import time
importlib.reload(DatabaseFunctions)

# Given an ini file with a request, can create database traces from input files (e.g., .dat, .csv, etc.)
WD = DatabaseFunctions.MakeTraces(ini='ini_files/WriteTraces.yml')

# Given an ini file with a request, can create database traces from google sheets
# Assumes local (daylight/standard) time, will auto convert to local standard time
WG = DatabaseFunctions.GSheetDump(ini='ini_files/WriteTraces_GSheets.yml')
# Out:
# Initialized using db_root:  W:/
# Loaded W:/Calculation_Procedures/TraceAnalysis_ini/_config.yml
# Loaded ini_files/WriteTraces.yml
# Processing:  BBS_Flux_Station {'siteID': 'BBS', 'inputData': '**Datadump**/**siteID**/EC_Station/', 'fileNamePatterns': 'BBS.MET\n', 'subfolder': 'Met', 'dateCols': 'TIMESTAMP', 'dateFmt': 'Auto', 'is_dst': False, 'headerRow': 1, 'firstDataRow': 3, 'exclude': 'RECORD', 'readme': 'Data from the BBS Flux Station - see the program currently running on the logger here https://github.com/ubc-micromet/DataLogger_Programs/tree/main/BBS', 'copy_to': '**SitesFolder**/**siteID**/EC_Station/'}
# X:/BBS/EC_Station/2023\20230616/TOA5_BBS.MET_2023_06_14_1500.dat
# X:/BBS/EC_Station/2023\20230626/TOA5_BBS.MET_2023_06_15_2230.dat
# X:/BBS/EC_Station/2023\20230705/TOA5_BBS.MET_2023_06_26_1400.dat
# X:/BBS/EC_Station/2023\20230705/TOA5_BBS.MET_2023_07_05_0900.dat
# X:/BBS/EC_Station/2023\20230721/TOA5_BBS.MET_2023_07_05_1130.dat
# X:/BBS/EC_Station/2023\20230822/TOA5_BBS.MET_2023_07_21_1700.dat
# X:/BBS/EC_Station/2023\20230929/TOA5_BBS.MET_2023_09_15_1430.dat
# X:/BBS/EC_Station/2023\20231030/TOA5_BBS.MET_2023_09_15_1430.dat
# X:/BBS/EC_Station/2023\20231107/TOA5_BBS.MET_2023_09_15_1430.dat
# X:/BBS/EC_Station/2023\20231123/TOA5_BBS.MET_2023_09_16_0900.dat
# X:/BBS/EC_Station/2023\20231130/TOA5_BBS.MET_2023_09_23_0300.dat
# X:/BBS/EC_Station/2024\20240213/TOA5_BBS.MET2_2024_02_03_1400.dat
# X:/BBS/EC_Station/2024\20240213/TOA5_BBS.MET3_2024_02_03_1400.dat
# X:/BBS/EC_Station/2024\20240213/TOA5_BBS.MET_1WeekUp_2024_02_03_1400.dat
# X:/BBS/EC_Station/2024\20240213/TOA5_BBS.MET_2024_02_03_1400.dat
# X:/BBS/EC_Station/2024\20240223/TOA5_BBS.MET_2024_02_03_1400.dat
# X:/BBS/EC_Station/2024\20240307/TOA5_BBS.MET_2024_02_03_1400.dat
# X:/BBS/EC_Station/2024\20240416/TOA5_BBS.MET_2024_03_07_1530.dat
# Processing:  BBS_PSW_S {'siteID': 'BBS', 'inputData': '**Datadump**/**siteID**/Chamberdata/Loggerdata', 'fileNamePatterns': 'CR10X_PSW_S', 'subfolder': 'Met', 'prefix': 'PSW_S', 'subtable': {'HH': {'ID': 121, 'headerList': {'ID': None, 'Year': 'YYYY', 'Day': 'DOY', 'Hour_Minute': 'HHMM', 'PannelTemp': 'degC', 'TSoil_5cm': 'degC', 'TSoil_10cm': 'degC', 'TSoil_30cm': 'degC', 'VWC': '%', 'pa': 'us', 'WTH': 'm', 'TWater': 'C'}}, 'DD': {'ID': 122, 'headerList': {'ID': None, 'Year': 'YYYY', 'Day': 'DOY', 'Hour_Minute': 'HHMM', 'BattV_MIN': 'V', 'ProgSig': None}}}, 'dateCols': 'Year Day Hour_Minute', 'dateFmt': '%Y%j%H%M', 'is_dst': False, 'firstDataRow': 0, 'exclude': 'ID ProgSig\n', 'readme': 'Data from the BBS Pine sphagnum woodland (PSW) seedling (S) Station - see the program currently running on the logger here https://github.com/ubc-micromet/DataLogger_Programs/tree/main/BBS'}
# X:/BBS/Chamberdata/Loggerdata\20230321/CR10X_PSW_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230404/CR10X_PSW_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230412/CR10X_PSW_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230424/CR10X_PSW_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230519/CR10X_PSW_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230531/CR10X_PSW_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230607/CR10X_PSW_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230614/CR10X_PSW_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230628/CR10X_PSW_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230719/CR10X_PSW_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230728/CR10X_PSW_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230804/CR10X_PSW_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230818/CR10X_PSW_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230915/CR10X_PSW_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20231014/CR10X_PSW_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20231114/CR10X_PSW_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20231220/CR10X_PSW_S_final_storage_1 (1).dat
# X:/BBS/Chamberdata/Loggerdata\20240115/CR10X_PSW_S_final_storage_1 (2).dat
# X:/BBS/Chamberdata/Loggerdata\20240217/CR10X_PSW_S_final_storage_1 (2).dat
# X:/BBS/Chamberdata/Loggerdata\20240316/CR10X_PSW_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20240413/CR10X_PSW_S_final_storage_1.dat
# Writing: W:/2023/BBS/Met/PSW_S_Year
# Writing: W:/2023/BBS/Met/PSW_S_Day
# Writing: W:/2023/BBS/Met/PSW_S_Hour_Minute
# Writing: W:/2023/BBS/Met/PSW_S_PannelTemp
# Writing: W:/2023/BBS/Met/PSW_S_TSoil_5cm
# Writing: W:/2023/BBS/Met/PSW_S_TSoil_10cm
# Writing: W:/2023/BBS/Met/PSW_S_TSoil_30cm
# Writing: W:/2023/BBS/Met/PSW_S_VWC
# Writing: W:/2023/BBS/Met/PSW_S_pa
# Writing: W:/2023/BBS/Met/PSW_S_WTH
# Writing: W:/2023/BBS/Met/PSW_S_TWater
# Writing: W:/2023/BBS/Met/clean_tv
# Writing: W:/2024/BBS/Met/PSW_S_Year
# Writing: W:/2024/BBS/Met/PSW_S_Day
# Writing: W:/2024/BBS/Met/PSW_S_Hour_Minute
# Writing: W:/2024/BBS/Met/PSW_S_PannelTemp
# Writing: W:/2024/BBS/Met/PSW_S_TSoil_5cm
# Writing: W:/2024/BBS/Met/PSW_S_TSoil_10cm
# Writing: W:/2024/BBS/Met/PSW_S_TSoil_30cm
# Writing: W:/2024/BBS/Met/PSW_S_VWC
# Writing: W:/2024/BBS/Met/PSW_S_pa
# Writing: W:/2024/BBS/Met/PSW_S_WTH
# Writing: W:/2024/BBS/Met/PSW_S_TWater
# Writing: W:/2024/BBS/Met/clean_tv
# Writing: W:/2023/BBS/Met/PSW_S_Year
# Writing: W:/2023/BBS/Met/PSW_S_Day
# Writing: W:/2023/BBS/Met/PSW_S_Hour_Minute
# Writing: W:/2023/BBS/Met/PSW_S_BattV_MIN
# Writing: W:/2023/BBS/Met/clean_tv
# Writing: W:/2024/BBS/Met/PSW_S_Year
# Writing: W:/2024/BBS/Met/PSW_S_Day
# Writing: W:/2024/BBS/Met/PSW_S_Hour_Minute
# Writing: W:/2024/BBS/Met/PSW_S_BattV_MIN
# Writing: W:/2024/BBS/Met/clean_tv
# Processing:  BBS_PSW_R {'siteID': 'BBS', 'inputData': '**Datadump**/**siteID**/Chamberdata/Loggerdata', 'fileNamePatterns': 'CR10X_PSW_R', 'subfolder': 'Met', 'prefix': 'PSW_R', 'subtable': {'HH': {'ID': 131, 'headerList': {'ID': None, 'Year': 'YYYY', 'Day': 'DOY', 'Hour_Minute': 'HHMM', 'PannelTemp': 'degC', 'TSoil_5cm': 'degC', 'TSoil_10cm': 'degC', 'TSoil_30cm': 'degC', 'VWC': '%', 'pa': 'us'}}, 'DD': {'ID': 132, 'headerList': {'ID': None, 'Year': 'YYYY', 'Day': 'DOY', 'Hour_Minute': 'HHMM', 'BattV_MIN': 'V', 'ProgSig': None}}}, 'dateCols': 'Year Day Hour_Minute', 'dateFmt': '%Y%j%H%M', 'is_dst': False, 'firstDataRow': 0, 'exclude': 'ID ProgSig\n', 'readme': 'Data from the BBS Pine sphagnum woodland (PSW) seedling removed (r) Station - see the program currently running on the logger here https://github.com/ubc-micromet/DataLogger_Programs/tree/main/BBS'}
# X:/BBS/Chamberdata/Loggerdata\20230321/CR10X_PSW_R_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230404/CR10X_PSW_R_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230412/CR10X_PSW_R_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230424/CR10X_PSW_R_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230519/CR10X_PSW_R_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230524/CR10X_PSW_R_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230614/CR10X_PSW_R_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230628/CR10X_PSW_R_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230719/CR10X_PSW_R_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230804/CR10X_PSW_R_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230818/CR10X_PSW_R_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230915/CR10X_PSW_R_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20231014/CR10X_PSW_R_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20231114/CR10X_PSW_R_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20231213/CR10X_PSW_R_final_storage_1 (1).dat
# X:/BBS/Chamberdata/Loggerdata\20240115/CR10X_PSW_R_final_storage_1 (2).dat
# X:/BBS/Chamberdata/Loggerdata\20240217/CR10X_PSW_R_final_storage_1 (2).dat
# X:/BBS/Chamberdata/Loggerdata\20240316/CR10X_PSW_R_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20240413/CR10X_PSW_R_final_storage_1.dat
# Writing: W:/2023/BBS/Met/PSW_R_Year
# Writing: W:/2023/BBS/Met/PSW_R_Day
# Writing: W:/2023/BBS/Met/PSW_R_Hour_Minute
# Writing: W:/2023/BBS/Met/PSW_R_PannelTemp
# Writing: W:/2023/BBS/Met/PSW_R_TSoil_5cm
# Writing: W:/2023/BBS/Met/PSW_R_TSoil_10cm
# Writing: W:/2023/BBS/Met/PSW_R_TSoil_30cm
# Writing: W:/2023/BBS/Met/PSW_R_VWC
# Writing: W:/2023/BBS/Met/PSW_R_pa
# Writing: W:/2023/BBS/Met/clean_tv
# Writing: W:/2024/BBS/Met/PSW_R_Year
# Writing: W:/2024/BBS/Met/PSW_R_Day
# Writing: W:/2024/BBS/Met/PSW_R_Hour_Minute
# Writing: W:/2024/BBS/Met/PSW_R_PannelTemp
# Writing: W:/2024/BBS/Met/PSW_R_TSoil_5cm
# Writing: W:/2024/BBS/Met/PSW_R_TSoil_10cm
# Writing: W:/2024/BBS/Met/PSW_R_TSoil_30cm
# Writing: W:/2024/BBS/Met/PSW_R_VWC
# Writing: W:/2024/BBS/Met/PSW_R_pa
# Writing: W:/2024/BBS/Met/clean_tv
# Writing: W:/2023/BBS/Met/PSW_R_Year
# Writing: W:/2023/BBS/Met/PSW_R_Day
# Writing: W:/2023/BBS/Met/PSW_R_Hour_Minute
# Writing: W:/2023/BBS/Met/PSW_R_BattV_MIN
# Writing: W:/2023/BBS/Met/clean_tv
# Writing: W:/2024/BBS/Met/PSW_R_Year
# Writing: W:/2024/BBS/Met/PSW_R_Day
# Writing: W:/2024/BBS/Met/PSW_R_Hour_Minute
# Writing: W:/2024/BBS/Met/PSW_R_BattV_MIN
# Writing: W:/2024/BBS/Met/clean_tv
# Processing:  BBS_PSTS {'siteID': 'BBS', 'inputData': '**Datadump**/**siteID**/Chamberdata/Loggerdata', 'fileNamePatterns': 'CR10X_PSTS', 'subfolder': 'Met', 'prefix': 'PSTS', 'subtable': {'HH': {'ID': 111, 'headerList': {'ID': None, 'Year': 'YYYY', 'Day': 'DOY', 'Hour_Minute': 'HHMM', 'PannelTemp': 'degC', 'S_TSoil_5cm': 'degC', 'S_TSoil_10cm': 'degC', 'S_TSoil_30cm': 'degC', 'R_TSoil_5cm': 'degC', 'R_TSoil_10cm': 'degC', 'R_TSoil_30cm': 'degC'}}, 'DD': {'ID': 112, 'headerList': {'ID': None, 'Year': 'YYYY', 'Day': 'DOY', 'Hour_Minute': 'HHMM', 'BattV_MIN': 'V', 'ProgSig': None}}}, 'dateCols': 'Year Day Hour_Minute', 'dateFmt': '%Y%j%H%M', 'is_dst': False, 'firstDataRow': 0, 'exclude': 'ID ProgSig\n', 'readme': 'Data from the BBS Pine sphagnum tall shrub (PSTS) both seedling (S) & removed (r) coverd by same Station - see the program currently running on the logger here https://github.com/ubc-micromet/DataLogger_Programs/tree/main/BBS'}
# X:/BBS/Chamberdata/Loggerdata\20230321/CR10X_PSTS_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230404/CR10X_PSTS_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230412/CR10X_PSTS_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230414/CR10X_PSTS_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230424/CR10X_PSTS_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230519/CR10X_PSTS_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230614/CR10X_PSTS_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230628/CR10X_PSTS_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230719/CR10X_PSTS_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230804/CR10X_PSTS_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230818/CR10X_PSTS_final_storage_1 (1).dat
# X:/BBS/Chamberdata/Loggerdata\20230915/CR10X_PSTS_final_storage_1 (1).dat
# X:/BBS/Chamberdata/Loggerdata\20231014/CR10X_PSTS_final_storage_1 (1).dat
# X:/BBS/Chamberdata/Loggerdata\20231114/CR10X_PSTS_final_storage_1 (1).dat
# X:/BBS/Chamberdata/Loggerdata\20231213/CR10X_PSTS_final_storage_1 (2).dat
# X:/BBS/Chamberdata/Loggerdata\20240115/CR10X_PSTS_final_storage_1 (3).dat
# X:/BBS/Chamberdata/Loggerdata\20240217/CR10X_PSTS_final_storage_1 (3).dat
# X:/BBS/Chamberdata/Loggerdata\20240316/CR10X_PSTS_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20240413/CR10X_PSTS_final_storage_1.dat
# Writing: W:/2023/BBS/Met/PSTS_Year
# Writing: W:/2023/BBS/Met/PSTS_Day
# Writing: W:/2023/BBS/Met/PSTS_Hour_Minute
# Writing: W:/2023/BBS/Met/PSTS_PannelTemp
# Writing: W:/2023/BBS/Met/PSTS_S_TSoil_5cm
# Writing: W:/2023/BBS/Met/PSTS_S_TSoil_10cm
# Writing: W:/2023/BBS/Met/PSTS_S_TSoil_30cm
# Writing: W:/2023/BBS/Met/PSTS_R_TSoil_5cm
# Writing: W:/2023/BBS/Met/PSTS_R_TSoil_10cm
# Writing: W:/2023/BBS/Met/PSTS_R_TSoil_30cm
# Writing: W:/2023/BBS/Met/clean_tv
# Writing: W:/2024/BBS/Met/PSTS_Year
# Writing: W:/2024/BBS/Met/PSTS_Day
# Writing: W:/2024/BBS/Met/PSTS_Hour_Minute
# Writing: W:/2024/BBS/Met/PSTS_PannelTemp
# Writing: W:/2024/BBS/Met/PSTS_S_TSoil_5cm
# Writing: W:/2024/BBS/Met/PSTS_S_TSoil_10cm
# Writing: W:/2024/BBS/Met/PSTS_S_TSoil_30cm
# Writing: W:/2024/BBS/Met/PSTS_R_TSoil_5cm
# Writing: W:/2024/BBS/Met/PSTS_R_TSoil_10cm
# Writing: W:/2024/BBS/Met/PSTS_R_TSoil_30cm
# Writing: W:/2024/BBS/Met/clean_tv
# Writing: W:/2023/BBS/Met/PSTS_Year
# Writing: W:/2023/BBS/Met/PSTS_Day
# Writing: W:/2023/BBS/Met/PSTS_Hour_Minute
# Writing: W:/2023/BBS/Met/PSTS_BattV_MIN
# Writing: W:/2023/BBS/Met/clean_tv
# Writing: W:/2024/BBS/Met/PSTS_Year
# Writing: W:/2024/BBS/Met/PSTS_Day
# Writing: W:/2024/BBS/Met/PSTS_Hour_Minute
# Writing: W:/2024/BBS/Met/PSTS_BattV_MIN
# Writing: W:/2024/BBS/Met/clean_tv
# Processing:  BBS_PSLS {'siteID': 'BBS', 'inputData': '**Datadump**/**siteID**/Chamberdata/Loggerdata', 'fileNamePatterns': 'CR10X_PSLS', 'subfolder': 'Met', 'prefix': 'PSLS', 'subtable': {'HH': {'ID': 101, 'headerList': {'ID': None, 'Year': 'YYYY', 'Day': 'DOY', 'Hour_Minute': 'HHMM', 'PannelTemp': 'degC', 'S_old_TSoil_5cm': 'degC', 'S_old_TSoil_10cm': 'degC', 'S_old_TSoil_30cm': 'degC', 'R_TSoil_5cm': 'degC', 'R_TSoil_10cm': 'degC', 'R_TSoil_30cm': 'degC'}}, 'DD': {'ID': 102, 'headerList': {'ID': None, 'Year': 'YYYY', 'Day': 'DOY', 'Hour_Minute': 'HHMM', 'BattV_MIN': 'V', 'ProgSig': None}}}, 'dateCols': 'Year Day Hour_Minute', 'dateFmt': '%Y%j%H%M', 'is_dst': False, 'firstDataRow': 0, 'exclude': 'ID ProgSig\n', 'readme': 'Data from the BBS Pine sphagnum low shrub (PSLS) seedling removed (r) ...  (S) data are bad/old and can be ignored - see the program currently running on the logger here https://github.com/ubc-micromet/DataLogger_Programs/tree/main/BBS'}
# X:/BBS/Chamberdata/Loggerdata\20230321/CR10X_PSLS_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230404/CR10X_PSLS_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230412/CR10X_PSLS_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230414/CR10X_PSLS_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230424/CR10X_PSLS_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230424/CR10X_PSLS_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230519/CR10X_PSLS_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230519/CR10X_PSLS_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230614/CR10X_PSLS_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230614/CR10X_PSLS_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230628/CR10X_PSLS_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230628/CR10X_PSLS_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230719/CR10X_PSLS_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230719/CR10X_PSLS_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230804/CR10X_PSLS_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230804/CR10X_PSLS_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230818/CR10X_PSLS_final_storage_1 (1).dat
# X:/BBS/Chamberdata/Loggerdata\20230818/CR10X_PSLS_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230915/CR10X_PSLS_final_storage_1 (1).dat
# X:/BBS/Chamberdata/Loggerdata\20230915/CR10X_PSLS_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20231014/CR10X_PSLS_final_storage_1 (1).dat
# X:/BBS/Chamberdata/Loggerdata\20231014/CR10X_PSLS_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20231114/CR10X_PSLS_final_storage_1 (1).dat
# X:/BBS/Chamberdata/Loggerdata\20231114/CR10X_PSLS_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20231213/CR10X_PSLS_final_storage_1 (2).dat
# X:/BBS/Chamberdata/Loggerdata\20231213/CR10X_PSLS_S_final_storage_1 (1).dat
# X:/BBS/Chamberdata/Loggerdata\20240115/CR10X_PSLS_final_storage_1 (3).dat
# X:/BBS/Chamberdata/Loggerdata\20240115/CR10X_PSLS_S_final_storage_1 (2).dat
# X:/BBS/Chamberdata/Loggerdata\20240217/CR10X_PSLS_final_storage_1 (3).dat
# X:/BBS/Chamberdata/Loggerdata\20240217/CR10X_PSLS_S_final_storage_1 (2).dat
# X:/BBS/Chamberdata/Loggerdata\20240316/CR10X_PSLS_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20240316/CR10X_PSLS_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20240413/CR10X_PSLS_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20240413/CR10X_PSLS_S_final_storage_1.dat
# Processing:  BBS_PSLS_S {'siteID': 'BBS', 'inputData': '**Datadump**/**siteID**/Chamberdata/Loggerdata', 'fileNamePatterns': 'CR10X_PSLS_S', 'subfolder': 'Met', 'prefix': 'PSLS_S', 'subtable': {'HH': {'ID': 141, 'headerList': {'ID': None, 'Year': 'YYYY', 'Day': 'DOY', 'Hour_Minute': 'HHMM', 'PannelTemp': 'degC', 'TSoil_5cm': 'degC', 'TSoil_10cm': 'degC', 'TSoil_30cm': 'degC'}}, 'DD': {'ID': 142, 'headerList': {'ID': None, 'Year': 'YYYY', 'Day': 'DOY', 'Hour_Minute': 'HHMM', 'BattV_MIN': 'V', 'ProgSig': None}}}, 'dateCols': 'Year Day Hour_Minute', 'dateFmt': '%Y%j%H%M', 'is_dst': False, 'firstDataRow': 0, 'exclude': 'ID ProgSig\n', 'readme': 'Data from the BBS Pine sphagnum low shrub (PSLS) seedling (S) data - see the program currently running on the logger here https://github.com/ubc-micromet/DataLogger_Programs/tree/main/BBS'}
# X:/BBS/Chamberdata/Loggerdata\20230424/CR10X_PSLS_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230519/CR10X_PSLS_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230614/CR10X_PSLS_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230628/CR10X_PSLS_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230719/CR10X_PSLS_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230804/CR10X_PSLS_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230818/CR10X_PSLS_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20230915/CR10X_PSLS_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20231014/CR10X_PSLS_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20231114/CR10X_PSLS_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20231213/CR10X_PSLS_S_final_storage_1 (1).dat
# X:/BBS/Chamberdata/Loggerdata\20240115/CR10X_PSLS_S_final_storage_1 (2).dat
# X:/BBS/Chamberdata/Loggerdata\20240217/CR10X_PSLS_S_final_storage_1 (2).dat
# X:/BBS/Chamberdata/Loggerdata\20240316/CR10X_PSLS_S_final_storage_1.dat
# X:/BBS/Chamberdata/Loggerdata\20240413/CR10X_PSLS_S_final_storage_1.dat
# Writing: W:/2023/BBS/Met/PSLS_S_Year
# Writing: W:/2023/BBS/Met/PSLS_S_Day
# Writing: W:/2023/BBS/Met/PSLS_S_Hour_Minute
# Writing: W:/2023/BBS/Met/PSLS_S_PannelTemp
# Writing: W:/2023/BBS/Met/PSLS_S_TSoil_5cm
# Writing: W:/2023/BBS/Met/PSLS_S_TSoil_10cm
# Writing: W:/2023/BBS/Met/PSLS_S_TSoil_30cm
# Writing: W:/2023/BBS/Met/clean_tv
# Writing: W:/2024/BBS/Met/PSLS_S_Year
# Writing: W:/2024/BBS/Met/PSLS_S_Day
# Writing: W:/2024/BBS/Met/PSLS_S_Hour_Minute
# Writing: W:/2024/BBS/Met/PSLS_S_PannelTemp
# Writing: W:/2024/BBS/Met/PSLS_S_TSoil_5cm
# Writing: W:/2024/BBS/Met/PSLS_S_TSoil_10cm
# Writing: W:/2024/BBS/Met/PSLS_S_TSoil_30cm
# Writing: W:/2024/BBS/Met/clean_tv
# Writing: W:/2023/BBS/Met/PSLS_S_Year
# Writing: W:/2023/BBS/Met/PSLS_S_Day
# Writing: W:/2023/BBS/Met/PSLS_S_Hour_Minute
# Writing: W:/2023/BBS/Met/PSLS_S_BattV_MIN
# Writing: W:/2023/BBS/Met/clean_tv
# Writing: W:/2024/BBS/Met/PSLS_S_Year
# Writing: W:/2024/BBS/Met/PSLS_S_Day
# Writing: W:/2024/BBS/Met/PSLS_S_Hour_Minute
# Writing: W:/2024/BBS/Met/PSLS_S_BattV_MIN
# Writing: W:/2024/BBS/Met/clean_tv
# Initialized using db_root:  W:/
# Loaded W:/Calculation_Procedures/TraceAnalysis_ini/_config.yml
# Loaded ini_files/WriteTraces_GSheets.yml
# Processing:  BBS_CH
#                   mean        std
# Date
# 2023-05-31  194.853659  50.127618
# 2023-08-22  216.853659  58.256571
# 2023-11-23  228.243902  74.990593
# 2024-02-13  245.121951  74.741620
# Writing: W:/2023/BBS/Met/Manual/CH_mean
# Writing: W:/2023/BBS/Met/Manual/CH_std
# Writing: W:/2023/BBS/Met/Manual/clean_tv
# Writing: W:/2024/BBS/Met/Manual/CH_mean
# Writing: W:/2024/BBS/Met/Manual/CH_std
# Writing: W:/2024/BBS/Met/Manual/clean_tv

# %%
# [False for]
# Out:
# True

# %%
# Given an ini file with a request, can create .csv files from database traces
# By default will process request for each site/year
# Passing Sites =['BB','BB2'] or Years = [2022,2023] etc. can be used to restrict request

ini={'data':{
    'Traces':{
        'h2o_mixing_ratio':{
            'Units': 'mmol+1mol_d-1',
            'output_name': 'h2o_mixing_ratio'
            },
        },
    'filename': 'Test.csv',
    'na_value': np.nan,
    'output_path': 'C:/Users/User/Teaching/GEOS300/GEOS300.github.io/_Test/',
    'stage': 'Flux/'}
    }

RD = DatabaseFunctions.MakeCSV(Sites = ['BB'],
                                Years = [y for y in range(2015,2017)], 
                                ini = ini)

# %%
if 'by_year' in ini['data'].keys() and self.ini[req]['by_year']:
    print(a)

# %%
FI = [69+22/60+20.20/3600, 134+52/60+51.92/3600]
IL = [69+28/60+47.5/3600, 134+35/60+18.7/3600]
print(FI)
print(IL)

# %%
type('a')==str

# %%
unitDict = {key:RD.ini['EP_BIOMET_OUTPUTS']['Traces'][key]['Units'] for key in RD.ini['EP_BIOMET_OUTPUTS']['Traces'].keys()}
unitDict

# %%
import json
import configparser

conf = configparser.ConfigParser()
conf.read('ini_files/Write_CSV_Files.ini')

Biom = dict(conf['FFP_Inputs'])

Trace_Deffs = {'Traces':{}}
# for in_name,out_name,units in zip(Biom['traces'].split(','),Biom['rename'].split(','),Biom['units'].split(',')):
for in_name,units in zip(Biom['traces'].split(','),Biom['units'].split(',')):
    Trace_Deffs['Traces'][in_name] = {'Units':units,'output_name':in_name}
Trace_Deffs['timestamp'] = {'timestamp_fmt':Biom['timestamp_fmt'],'timestamp_units':Biom['timestamp_units'],'output_name':Biom['timestamp']}
for i in [ 'units_in_header','output_path','by_year','stage']:
    Trace_Deffs[i] = Biom[i]
Trace_Deffs['na_value'] = 'np.nan'
Trace_Deffs['filename'] = 'np.nan'
# Biom
with open('ini_files/Write_FFP_Input_CSV.json', 'w') as f:
    json.dump(Trace_Deffs, f,indent=2)

# with open('ini_files/Write_Biomet_CSV.json') as jsonfile:
#     # `json.loads` parses a string in json format
#     Trace_Deffs = json.load(jsonfile)
Biom

# %% [markdown]
# # Downloading NARR
#
# * Can expand to ECCC Data and various other products if needed

# %%
import ExtractNARR
import importlib
import time
importlib.reload(ExtractNARR)
T1 = time.time()
EX = ExtractNARR.PointSample([2021,2022,2023],Limit_to_Sites=['DM','RM','NM','NS','NOB','NFB'])
print(time.time()-T1)

# %%
import TzFuncs
import importlib
import pandas as pd
importlib.reload(TzFuncs)

# Convert FROM UTC
input = pd.date_range(start='2023-03-11 23:00',end='2023-03-12 08:00',freq='1H')
tzf = TzFuncs.Tzfuncs(Time_Zone='Etc/GMT-8')
tzf.convert(input,from_UTC=True)
print('UTC input:')
print(input)
print('Standard Time (non-TZ aware):')
print(tzf.Standard_Time)
print('Local Time (TZ aware):')
print(tzf.UTC_Time)
print('UTC Time (TZ aware):')
print(tzf.Local_Time)

# Convert FROM America/Vancouver (DST) to standard time & UTC time
input = pd.date_range(start='2023-03-11 23:00',end='2023-03-12 08:00',freq='1H')
tzf = TzFuncs.Tzfuncs(Time_Zone='America/Vancouver',DST=True)
tzf.convert(input,to_UTC=True)
print('America/Vancouver input:')
print(input)
print('Standard Time (non-TZ aware):')
print(tzf.Standard_Time)
print('Local Time (TZ & DST aware):')
print(tzf.UTC_Time)
print('UTC Time (TZ aware):')
print(tzf.Local_Time)

# %% [markdown]
# # Make a spatial config

# %%
import os
import importlib
import MakeSpatialConfigFile
importlib.reload(MakeSpatialConfigFile)

for site,start_year in zip(['BB','BB2','DSM','RBM','HOGG','YOUNG'],
                            [2015,2019,2021,2022,2021,2020]):
    root = f'Y:/{site}/raw/2023/01/'
    out = f'Y:/{site}/footprint/'
    for file in os.listdir(root):
        if file.endswith('.ghg'):
            print(f'Creating site config for {site} from {root+file}')
            MakeSpatialConfigFile.from_GHG(site,root+file,start_year,out)
            break


for site,start_year in zip(['OHM'],
                           [2023]):
    root = f'Y:/{site}/raw/2023/06/'
    out = f'Y:/{site}/footprint/'
    for file in os.listdir(root):
        if file.endswith('.ghg'):
            print(f'Creating site config for {site} from {root+file}')
            MakeSpatialConfigFile.from_GHG(site,root+file,start_year,out)
            break

# %%
import os
import sys
import yaml
# To find database_default from inside (the root) of a project folder
def get_matlab_default(fn="Matlab/biomet_database_default.m"):
    # Read .m file as "text"
    with open(fn,encoding='utf8') as db:
        config = db.read()
        config = config.split('if ispc')[1].split('elseif ismac')
        # Identify system, translate Matlab to Python, and evaluate
        if sys.platform == 'win32':
            exec(config[0].replace('%','#').replace(' ','').replace('\\','/'))
        elif sys.platform == 'darwin':
            exec(config[1].replace('%','#').replace(' ','').replace('\\','/'))
    return(x)

def get_config(fn='_config.yml'):
    with open(fn) as f:
        config = yaml.safe_load(f)
    return(config['Database']['root'])

os.chdir('C:/Users/User')

config_fn = '_config.yml'
matlab_fn = 'Matlab/biomet_database_default.m'

# 1 Search for _config.yml in root of Project Folder
if os.path.isfile(config_fn):
    db_root = get_config(config_fn)

# 2 Search for matalab default in root of project folder
elif os.path.isfile(matlab_fn):
    db_root = get_matlab_default(matlab_fn)

# 3 Search environment variables for UBC_PC_Setup
# Repeat 1 & 2, prompt for input as last resort
else:
    pth = [v for v in os.environ.values() if 'UBC_PC_Setup' in v]
    if len(pth)>0:
        if os.path.isfile(pth[0]+config_fn):
            db_root = get_config(pth[0]+config_fn)
        elif os.path.isfile(pth[0]+matlab_fn):
            db_root = get_matlab_default(pth[0]+matlab_fn)
    else:
        db_root = input('No default database path found, input path to database:')

# %%
import traceback
import sys

try:
    1-a
except Exception:
    e = (traceback.format_exc())
    # or
    # print(sys.exc_info()[2])
    pass
print('Continue on my merry way!')

# %%
# import pandas as pd
# df = pd.DataFrame(data={'1':[1]},index=[1])
# if '1' in df.columns:
#     print('!')
e

# %%
type(e)
